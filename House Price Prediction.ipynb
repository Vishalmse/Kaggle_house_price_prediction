# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('train.csv')
# pd.set_option('display.max_rows', 999)
pd.set_option('display.max_columns', 999)
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
data.describe(include = "all")
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %% [markdown]
# ## Dropping feature which have more missing value then 50% of dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
data.drop(['Id','Alley','PoolQC','Fence','MiscFeature'], axis=1, inplace=True)

# %% [markdown]
# ## Dealing with missing values

# %%
data['LotFrontage'] = data['LotFrontage'].fillna(data['LotFrontage'].mean())
data['MasVnrType'] = data['MasVnrType'].fillna(data['MasVnrType'].mode()[0])
data['MasVnrArea'] = data['MasVnrArea'].fillna(data['MasVnrArea'].mean())
data['BsmtQual'] = data['BsmtQual'].fillna(data['BsmtQual'].mode()[0])
data['BsmtCond'] = data['BsmtCond'].fillna(data['BsmtCond'].mode()[0])
data['BsmtExposure'] = data['BsmtExposure'].fillna(data['BsmtExposure'].mode()[0])
data['BsmtFinType1'] = data['BsmtFinType1'].fillna(data['BsmtFinType1'].mode()[0])
data['BsmtFinType2'] = data['BsmtFinType2'].fillna(data['BsmtFinType2'].mode()[0])
data['Electrical'] = data['Electrical'].fillna(data['Electrical'].mode()[0])
data['FireplaceQu'] = data['FireplaceQu'].fillna(data['FireplaceQu'].mode()[0])
data['GarageType'] = data['GarageType'].fillna(data['GarageType'].mode()[0])
data['GarageYrBlt'] = data['GarageYrBlt'].fillna(data['GarageYrBlt'].mean())
data['GarageFinish'] = data['GarageFinish'].fillna(data['GarageFinish'].mode()[0])
data['GarageQual'] = data['GarageQual'].fillna(data['GarageQual'].mode()[0])
data['GarageCond'] = data['GarageCond'].fillna(data['GarageCond'].mode()[0])

# %%
clean_train_data = data.copy()
clean_train_data.shape
# Out:
# (1460, 76)

# %% [markdown]
# ## Merging train and test data to get dummies for both data

# %%
clean_test_data = pd.read_csv('clean_test_data')

# %%
final_df = pd.concat([clean_train_data,clean_test_data], axis=0)
final_df.shape
# Out:
# (2919, 76)

# %% [markdown]
# ## creating dummy variable

# %%
def get_dummy(list_columns, final_df):
    df_final = final_df
    i = 0
    for field in list_columns:
        print(field)
        df1 = pd.get_dummies(final_df[field], drop_first=True)
        
        final_df.drop([field], axis=1, inplace=True)
        if i == 0:
            df_final= df1.copy()
        else:
            final_df= pd.concat([final_df, df1], axis=1)
        i += 1
    
    final_df = pd.concat([final_df, df_final], axis=1)
    
    return final_df

# %%
# make list of all catogerical data
columns = []
for i in clean_train_data:
    if clean_train_data[i].dtypes == "O":
        columns.append(i)
len(columns)
# Out:
# 39

# %%
final_df = get_dummy(columns, final_df)
# Out:
# MSZoning
# Street
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive
# SaleType
# SaleCondition

# %%
final_df = final_df.loc[:, ~final_df.columns.duplicated()]
final_df.shape
# Out:
# (2919, 177)

# %%
df_train = final_df.iloc[:1460,:]
df_test = final_df.iloc[1460:,:]

# %%
df_test.drop(['SalePrice'], axis=1, inplace=True)
# Out:
# E:\anaconda\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# ## Declare vaiables

# %%
train_input = df_train.drop('SalePrice', axis=1)
train_output = df_train['SalePrice']

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import VotingRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
import sklearn
sorted(sklearn.metrics.SCORERS.keys())
# Out:
# ['accuracy',
#  'adjusted_mutual_info_score',
#  'adjusted_rand_score',
#  'average_precision',
#  'balanced_accuracy',
#  'completeness_score',
#  'explained_variance',
#  'f1',
#  'f1_macro',
#  'f1_micro',
#  'f1_samples',
#  'f1_weighted',
#  'fowlkes_mallows_score',
#  'homogeneity_score',
#  'jaccard',
#  'jaccard_macro',
#  'jaccard_micro',
#  'jaccard_samples',
#  'jaccard_weighted',
#  'max_error',
#  'mutual_info_score',
#  'neg_brier_score',
#  'neg_log_loss',
#  'neg_mean_absolute_error',
#  'neg_mean_gamma_deviance',
#  'neg_mean_poisson_deviance',
#  'neg_mean_squared_error',
#  'neg_mean_squared_log_error',
#  'neg_median_absolute_error',
#  'neg_root_mean_squared_error',
#  'normalized_mutual_info_score',
#  'precision',
#  'precision_macro',
#  'precision_micro',
#  'precision_samples',
#  'precision_weighted',
#  'r2',
#  'recall',
#  'recall_macro',
#  'recall_micro',
#  'recall_samples',
#  'recall_weighted',
#  'roc_auc',
#  'roc_auc_ovo',
# ...

# %%
tree_reg = DecisionTreeRegressor(random_state=0)
# kf = KFold(shuffle=True, n_splits=5)
tree_scores = cross_val_score(tree_reg,train_input,train_output,scoring='neg_mean_squared_error', cv=5)

# %%
np.mean(tree_scores)
# Out:
# -1681212373.2945206

# %%
random_reg = RandomForestRegressor(random_state=0)
random_score = cross_val_score(random_reg,train_input,train_output,scoring='neg_mean_squared_error', cv=5)

# %%
np.mean(random_score)
# Out:
# -941130116.9352156

# %%
gb_reg = GradientBoostingRegressor(random_state=0)
gb_scores = cross_val_score(gb_reg,train_input,train_output,scoring='neg_mean_squared_error',cv=5)

# %%
np.mean(gb_scores)
# Out:
# -675170081.8968971

# %%
xg_reg = XGBRegressor(objective='reg:linear', random_state=0)
xg_scores = cross_val_score(xg_reg,train_input,train_output,scoring='neg_mean_squared_error',cv=5)
# Out:
# [16:08:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
np.mean(xg_scores)
# Out:
# -718620809.6135466

# %%
vot_reg = VotingRegressor([('dsc', tree_reg), ('xg', xg_reg)])
vot_scores = cross_val_score(vot_reg,train_input,train_output,scoring='neg_mean_squared_error',cv=5)
# Out:
# [16:08:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
np.mean(vot_scores)
# Out:
# -944069972.5597973

# %%
vot_reg1 = VotingRegressor([('rf', random_reg), ('xg', xg_reg)])
vot_scores1 = cross_val_score(vot_reg,train_input,train_output,scoring='neg_mean_squared_error',cv=5)
# Out:
# [16:08:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
np.mean(vot_scores1)
# Out:
# -944069972.5597973

# %% [markdown]
# ## Hyperparameter Tunning (random forest)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
params_grid = {
    'n_estimators':[100,200,300,500,750,1000],
    'max_depth':[5,10,15,20,30,40,50,70],
    'min_samples_split':[2,4,8,16,20]
}

# %%
optimal_params = RandomizedSearchCV(estimator=random_reg,
                            param_distributions=params_grid, 
                            scoring='neg_mean_squared_error', 
                            cv=5)
optimal_params.fit(train_input,
                   train_output)
# Out:
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    ccp_alpha=0.0,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=100,
# ...

# %%
print(optimal_params.best_params_)
# Out:
# {'n_estimators': 1000, 'min_samples_split': 2, 'max_depth': 20}

# %%
# params_grid1 = {
#     'n_estimators':[1750],
#     'max_depth':[10,15,20],
#     'min_samples_split':[1,2,3],
#     'max_features':['auto', 'sqrt']
# }

# optimal_params1 = GridSearchCV(estimator=random_reg,
#                             param_grid=params_grid1, 
#                             scoring='neg_mean_squared_error',
#                             n_jobs=-1,
#                             cv=3)
# optimal_params1.fit(train_input,
#                    train_output)
# Out:
# GridSearchCV(cv=3, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=0,
#                                              verbose=0, warm_start=False),
# ...

# %%
print(optimal_params1.best_params_)
# Out:
# {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 1750}

# %% [markdown]
# ## Optimized random forest

# %%
random_reg_opt = RandomForestRegressor(n_estimators = 1750,
                                       max_depth=20,
                                       max_features='sqrt',
                                       min_samples_split=2,
                                       oob_score=True,
                                       random_state=0
                                      )
random_reg_opt.fit(train_input, train_output)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=1750, n_jobs=None, oob_score=True,
#                       random_state=0, verbose=0, warm_start=False)

# %%
print('Score: ', random_reg_opt.score(train_input, train_output))
print(random_reg_opt.oob_score_)
# Out:
# Score:  0.9809101643956859
# 0.8594170613862024

# %%
random_reg_opt1 = RandomForestRegressor(n_estimators = 1750,
                                       max_depth=20,
                                       min_samples_split=2,
                                       oob_score=True,
                                       random_state=0
                                       )
random_reg_opt1.fit(train_input, train_output)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=20, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=1750, n_jobs=None, oob_score=True,
#                       random_state=0, verbose=0, warm_start=False)

# %%
print('Score: ', random_reg_opt1.score(train_input, train_output))
print(random_reg_opt1.oob_score_)
# Out:
# Score:  0.9815720277535845
# 0.8636457305088985

# %%
random_scores1 = cross_val_score(random_reg_opt,train_input,train_output,scoring='neg_mean_squared_error',cv=10,n_jobs=-1)

# %%
np.mean(random_scores1)
# Out:
# -901174626.2647991

# %% [markdown]
# ## Optimized Xgboos

# %%
xg_reg_opt = XGBRegressor(objective='reg:linear',
                      learning_rate=0.1,
                      max_depth=6,
                      gamma=0,
                      reg_lambda=1.0,
                      colsample_bytree=0.8,
                      subsample=0.7,
                      random_state=0)
xg_reg_opt.fit(train_input, train_output)
# Out:
# [17:21:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.8, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=6, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1.0, scale_pos_weight=1, seed=None,
#              silent=None, subsample=0.7, verbosity=1)

# %%
xg_scores1 = cross_val_score(xg_reg_opt,train_input,train_output,scoring='neg_mean_squared_error',cv=10)
# Out:
# [17:21:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:21:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:21:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:21:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:21:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:21:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:22:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:22:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
np.mean(xg_scores1)
# Out:
# -775864204.645625

# %% [markdown]
# ## Voting Regressor

# %%
vot_reg2 = VotingRegressor([('rf', random_reg), ('xg', xg_reg_opt)])
vot_scores2 = cross_val_score(vot_reg2,train_input,train_output,scoring='neg_mean_squared_error',cv=10)
# Out:
# [19:17:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:17:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:17:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:17:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:17:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:18:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:18:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:18:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
np.mean(vot_scores2)
# Out:
# -798328969.1216271

# %%
vot_reg3 = VotingRegressor([('rf', random_reg_opt1), ('xg', xg_reg_opt)])
vot_scores3 = cross_val_score(vot_reg3,train_input,train_output,scoring='neg_mean_squared_error',cv=10,n_jobs=-1)

# %%
np.mean(vot_scores3)
# Out:
# -783414798.9947255

# %%
vot_reg3.fit(train_input,train_output)
# Out:
# [19:24:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# VotingRegressor(estimators=[('rf',
#                              RandomForestRegressor(bootstrap=True,
#                                                    ccp_alpha=0.0,
#                                                    criterion='mse',
#                                                    max_depth=20,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
# ...

# %% [markdown]
# ## Prediction

# %%
y_pred_opt = vot_reg3.predict(df_test)
y_pred_opt.shape
# Out:
# (1459,)

# %%
pred1 = pd.DataFrame(y_pred_opt)
sub_df = pd.read_csv('sample_submission.csv')
dataset1 = pd.concat([sub_df['Id'], pred1], axis=1)
dataset1.columns = ['Id', 'SalePrice']
dataset1.to_csv('sample_submission_vot2.csv', index=False)
